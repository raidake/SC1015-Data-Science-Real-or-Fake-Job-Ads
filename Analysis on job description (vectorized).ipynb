# %%
import numpy as np
import pandas as pd
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.metrics import classification_report

# %%
train_data = pd.read_csv('tokenized.csv', usecols=['fraudulent','lemm_tokens'])
train_data.head()
# Out:
#    fraudulent                                        lemm_tokens
# 0           0  ['we', 'food52', 'create', 'groundbreaking', '...
# 1           0  ['90', 'second', 'worlds', 'cloud', 'video', '...
# 2           0  ['valor', 'service', 'provide', 'workforce', '...
# 3           0  ['our', 'passion', 'improve', 'quality', 'life...
# 4           0  ['spotsource', 'solutions', 'llc', 'global', '...

# %%
print('Shape of training data :',train_data.shape)
# Out:
# Shape of training data : (17880, 2)

# %%
y = train_data["fraudulent"]
X = train_data["lemm_tokens"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=420)

# %%
tfidf = TfidfVectorizer()
tfidf.fit(X_train)
X_train_tfidf = tfidf.transform(X_train)
X_test_tfidf = tfidf.transform(X_test)
print(X_train_tfidf.shape)
print(X_test_tfidf.shape)
# Out:
# (14304, 81083)
# (3576, 81083)

# %% [markdown]
# # Check the words 'learnt' by vectorizer

# %%
tfidf.vocabulary_
# Out:
# {'unspecified': 72826,
#  'what': 76669,
#  'casumo': 10843,
#  'company': 13513,
#  'technology': 69297,
#  'startup': 65649,
#  'form': 27950,
#  '2012': 557,
#  'product': 52923,
#  'recognize': 55900,
#  'award': 7179,
#  'win': 76862,
#  'online': 45805,
#  'casino': 10820,
#  'concept': 14078,
#  'though': 70339,
#  'literally': 38471,
#  'whole': 76748,
#  'new': 44338,
#  'universe': 72684,
#  'we': 76234,
#  'work': 77137,
#  'change': 11375,
#  'common': 13207,
#  'perception': 48529,
#  'through': 70383,
#  'design': 18440,
#  'amp': 4039,
#  'innovation': 33876,
#  'aim': 3583,
#  'disrupt': 20265,
#  'young': 78072,
#  'many': 40204,
#  'ways': 76191,
#  'immature': 32535,
#  'industry': 33312,
#  'ignore': 32362,
#  'rule': 59877,
#  'found': 28113,
#  'upon': 72985,
#  'single': 62714,
#  'promise': 54076,
#  'want': 76052,
#  'deliver': 17786,
#  'world': 77453,
#  'best': 8263,
#  'game': 28883,
#  'experience': 25422,
#  'no': 44569,
#  'bullet': 9609,
#  'brand': 9093,
#  'book': 8856,
#  'believe': 8061,
#  'understand': 72530,
#  'data': 16816,
#  'play': 50080,
#  'key': 36445,
#  'role': 59456,
#  'goal': 29573,
#  'this': 70302,
#  'doingas': 20692,
#  'scientist': 60813,
#  'across': 2428,
#  'organization': 46600,
#  'provide': 54403,
#  'insights': 34016,
#  'research': 57948,
#  'help': 31062,
#  'transformative': 71612,
#  'business': 9673,
#  'as': 6036,
#  'part': 47823,
#  'cross': 15911,
#  'functional': 28564,
#  'team': 68529,
#  'particularly': 47852,
#  'close': 12457,
#  'engineer': 23019,
#  'producers': 52917,
#  'player': 50090,
#  'responsible': 58656,
#  'players': 50152,
#  'retention': 58875,
#  'you': 78034,
#  'together': 70870,
#  'smart': 63673,
#  'passionate': 48025,
#  'people': 48447,
#  'create': 15674,
#  'wrangle': 77553,
#  'organize': 46715,
#  'aggregate': 3461,
#  'analyze': 4330,
#  'gazillions': 29005,
#  'umptillions': 72419,
#  'gigabytes': 29354,
#  'perform': 48564,
#  'critical': 15842,
#  'analysis': 4095,
#  'order': 46473,
#  'drive': 21036,
#  'behaviour': 8008,
#  'actionable': 2446,
#  'community': 13404,
#  'aid': 3571,
#  'us': 74523,
#  'make': 39290,
#  'right': 59213,
#  'decisions': 17454,
#  'run': 59893,
#  'predictive': 51510,
#  'anticipatory': 4678,
#  'look': 38768,
#  'expand': 25299,
#  'rapidly': 55575,
#  'result': 58725,
#  'need': 43806,
#  'ramp': 55549,
#  'rank': 55565,
#  'relentless': 56717,
#  'quest': 55226,
#  'give': 29445,
#  'customers': 16355,
#  'good': 29728,
#  'include': 32956,
#  'get': 29279,
#  'offer': 45320,
#  'reward': 59077,
#  'correct': 15305,
#  'time': 70508,
#  'casumos': 10844,
#  'tick': 70440,
#  'search': 61095,
#  'razor': 55664,
#  'sharp': 62217,
#  'science': 60783,
#  'talent': 68106,
#  'goals': 29581,
#  'extraordinary': 26272,
#  'analytical': 4254,
#  'statistics': 65771,
#  'love': 38826,
#  'number': 44869,
#  'cruncher': 15951,
#  'like': 38219,
#  'mathematics': 40754,
#  'aremotivated': 5830,
#  'loyal': 38856,
#  'educate': 21711,
#  'hold': 31435,
#  'ph': 49028,
#  'bachelor': 7298,
#  'master': 40623,
#  'highly': 31273,
#  'numerate': 44887,
#  'field': 26948,
#  'computer': 14030,
#  'physics': 49404,
#  'apply': 5194,
#  'similar': 62569,
#  'able': 1790,
#  'ask': 6107,
#  'question': 55227,
#  'find': 27216,
#  'pattern': 48128,
#  'large': 37240,
#  'dimensional': 19833,
#  'set': 61988,
#  'in': 32876,
#  'structure': 66352,
#  'statistical': 65767,
#  'model': 42454,
#  'speak': 64626,
#  'linear': 38280,
#  'regression': 56399,
#  'logic': 38682,
#  'lunch': 38942,
#  'someone': 64393,
#  'past': 48055,
#  'life': 38130,
#  'comfortable': 13083,
#  'least': 37717,
#  'one': 45753,
#  'program': 53485,
#  'language': 37087,
#  'tool': 70951,
#  'combination': 13066,
#  'python': 54776,
#  'matlab': 40768,
#  'dbs': 17197,
#  'command': 13097,
#  'line': 38278,
#  'linux': 38358,
#  'also': 3874,
#  'know': 36632,
#  'machine': 39015,
#  'learn': 37610,
#  'happen': 30680,
#  'future': 28789,
#  'keen': 36374,
#  'aware': 7183,
#  'behavior': 7994,
#  'funnel': 28745,
#  'acquire': 2388,
#  'retain': 58866,
#  'exist': 25276,
#  'first': 27317,
#  'board': 8686,
#  'framework': 28194,
#  'thrive': 70378,
#  'happy': 30693,
#  'curious': 16280,
#  'friendly': 28446,
#  'flat': 27425,
#  'load': 38550,
#  'responsibility': 58609,
#  'freedom': 28352,
#  'mission': 42257,
#  'statementgood': 65707,
#  'home': 31479,
#  'care': 10621,
#  'commit': 13171,
#  'superior': 66992,
#  'safe': 59998,
#  'cost': 15364,
#  'effective': 21798,
#  'health': 30964,
#  'service': 61636,
#  'patients': 48112,
#  'live': 38499,
#  'independently': 33090,
#  'possible': 51023,
#  'seek': 61261,
#  'coordinate': 15166,
#  'agency': 3399,
#  'resources': 58141,
#  'decrease': 17542,
#  'burden': 9632,
#  'illness': 32426,
#  'unnecessary': 72764,
#  'duplication': 21238,
#  'lifestyle': 38181,
#  'improvements': 32814,
#  'positive': 51000,
#  'outcomes': 47115,
#  'our': 47075,
#  'visiongood': 75591,
#  'serve': 61562,
#  'every': 24899,
#  'counties': 15442,
#  'license': 38080,
#  'emphasize': 22691,
#  'honor': 31546,
#  'professionalism': 53296,
#  'excellence': 25029,
#  'to': 70808,
#  'premier': 51782,
#  'market': 40289,
#  'treat': 71764,
#  'patient': 48106,
#  'dignity': 19817,
#  'respect': 58195,
#  'remain': 56785,
#  'family': 26512,
#  'orient': 46769,
#  'operation': 45979,
#  'continually': 14855,
#  'grow': 30166,
#  'size': 62884,
#  'scope': 60834,
#  'maintain': 39190,
#  'high': 31239,
#  'standard': 65450,
#  'quality': 55065,
#  'establish': 24451,
#  'own': 47394,
#  'medicare': 41144,
#  'certify': 11245,
#  'weekend': 76481,
#  'holiday': 31447,
#  'intake': 34243,
#  'coordinator': 15179,
#  'join': 35972,
#  'commitment': 13172,
#  'supportive': 67226,
#  'environment': 23583,
#  'position': 50886,
#  'descriptionprocess': 18371,
#  'admissionswork': 2946,
#  'closely': 12469,
#  'call': 10077,
#  'administrator': 2910,
#  'rnmaintain': 59334,
#  'medical': 41139,
#  'record': 56007,
#  'keep': 36377,
#  'file': 27078,
#  'neat': 43686,
#  'complete': 13821,
#  'accordance': 1998,
#  'jcaho': 35750,
#  'standardsuploading': 65567,
#  'md': 40945,
#  'lab': 36959,
#  'progress': 53721,
#  'report': 56939,
#  'ect': 21629,
#  'chart': 11595,
#  'notify': 44749,
#  'appropriate': 5351,
#  'clinician': 12426,
#  'case': 10768,
#  'managermaking': 39847,
#  'admit': 2947,
#  'packets': 47538,
#  'clinicianstracking': 12429,
#  'discharge': 20059,
#  'documentshandle': 20615,
#  'phone': 49106,
#  'inquirestracking': 33947,
#  'hospitalize': 31608,
#  'lvn': 38975,
#  'prefer': 51524,
#  'years': 77904,
#  'office': 45366,
#  'strong': 66335,
#  'terminologymust': 69643,
#  'self': 61354,
#  'direct': 19889,
#  'possess': 51014,
#  'level': 37873,
#  'motivation': 42971,
#  'detail': 18831,
#  'degree': 17637,
#  'autonomy': 7064,
#  'meet': 41189,
#  'objectives': 45042,
#  'forth': 28055,
#  'administrationable': 2832,
#  'addition': 2729,
#  'partial': 47828,
#  'weekdays': 76477,
#  'proficient': 53374,
#  'use': 74591,
#  'computers': 14042,
#  'various': 75060,
#  'software': 63891,
#  'manage': 39410,
#  'multiple': 43212,
#  'prioritiesexcellent': 52179,
#  'write': 77567,
#  'verbal': 75248,
#  'communication': 13233,
#  'skills': 62939,
#  'historyfounded': 31363,
#  '1929': 412,
#  'earl': 21442,
#  'bertrand': 8249,
#  'bradley': 9061,
#  'begin': 7978,
#  'sell': 61363,
#  'products': 53076,
#  'knape': 36616,
#  'vogt': 75756,
#  'co': 12628,
#  'grand': 29908,
#  'rapids': 55579,
#  'michigan': 41895,
#  'with': 76974,
#  'open': 45911,
#  'los': 38796,
#  'angeles': 4535,
#  'branch': 9088,
#  'become': 7930,
#  'wholesale': 76756,
#  'distributor': 20331,
#  'specialize': 64693,
#  'store': 65964,
#  'fixture': 27380,
#  'specialty': 64705,
#  'hardware': 30721,
#  'drawer': 20979,
#  'slide': 63611,
#  'hinge': 31311,
#  'bracket': 9058,
#  'standards': 65466,
#  '1943': 415,
#  'offices': 45461,
#  'san': 60276,
#  'francisco': 28306,
#  'follow': 27733,
#  'seattle': 61131,
#  '1956': 425,
#  'the': 69983,
#  'late': 37269,
#  '1950': 418,
#  '1960': 430,
#  'add': 2716,
#  'wilsonart': 76857,
#  'pressure': 51965,
#  'laminate': 37034,
#  'mix': 42318,
#  'during': 21258,
#  '1970': 436,
#  'leadership': 37482,
#  'son': 64409,
#  'robert': 59380,
#  'sr': 65143,
#  'two': 72164,
#  'diego': 19721,
#  '1972': 439,
#  'portland': 50857,
#  '1976': 443,
#  'significant': 62524,
#  'additions': 2733,
#  'blum': 8670,
#  'european': 24733,
#  'accuride': 2309,
#  'precision': 51491,
#  'ball': 7516,
#  'bear': 7903,
#  'greater': 29985,
#  'emphasis': 22690,
#  'supplier': 67103,
#  'cabinet': 9952,
#  'furniture': 28767,
#  'industries': 33290,
#  'take': 68080,
#  'since': 62695,
#  'anaheim': 4073,
#  '1995': 467,
#  'consistently': 14554,
#  '1998': 470,
#  'enter': 23414,
#  'cold': 12878,
#  'press': 51954,
#  'lamination': 37036,
#  'locations': 38622,
#  'west': 76635,
#  'coast': 12653,
#  'subsidiary': 66629,
#  'pacific': 47481,
#  'northwest': 44677,
#  'marketplaces': 40489,
#  'ownershipup': 47423,
#  'january': 35558,
#  '2009': 541,
#  'operate': 45973,
#  '100': 105,
#  'on': 45707,
#  'industrial': 33286,
#  'opportunity': 46253,
#  'partner': 47881,
#  'iop': 34968,
#  'private': 52242,
#  'equity': 24144,
#  'firm': 27289,
#  'base': 7638,
#  'evanston': 24788,
#  'il': 32410,
#  'jr': 36113,
#  'aquiring': 5537,
#  'stock': 65917,
#  'subsidiaries': 66628,
#  'current': 16296,
#  'shareholders': 62190,
#  'available': 7100,
#  'locate': 38604,
#  'hayward': 30883,
#  'ca': 9939,
#  'location': 38606,
#  'ship': 62293,
#  'responsibilities': 58242,
#  'within': 76996,
#  'warehouse': 76071,
#  'distribution': 20313,
#  'essential': 24391,
#  'job': 35870,
#  'functionspicking': 28665,
#  'pack': 47483,
#  'stage': 65340,
#  'delivery': 17874,
#  'process': 52527,
#  'up': 72880,
#  'shipments': 62306,
#  'cycle': 16593,
#  'count': 15426,
#  'forklift': 27937,
#  'pallet': 47632,
#  'jack': 35521,
#  'truck': 71954,
#  'roll': 59620,
#  'housekeep': 31732,
#  'duties': 21264,
#  'area': 5723,
#  'clean': 12076,
#  'non': 44611,
#  'functionsback': 28622,
#  'will': 76825,
#  'departments': 18121,
#  'must': 43281,
#  'assist': 6368,
#  'others': 46977,
#  'additional': 2730,
#  'task': 68265,
#  'operations': 46004,
#  'manager': 39760,
#  'qualificationsbe': 54954,
#  'familiar': 26490,
#  'basic': 7708,
#  'knowledge': 36642,
#  'systems': 67687,
#  'rate': 55602,
#  'postage': 51065,
#  'calculator': 10024,
#  'ability': 1751,
#  'safety': 60010,
#  'relate': 56523,
#  'equipment': 24064,
#  'be': 7885,
#  'machinery': 39018,
#  'receive': 55833,
#  'inventory': 34826,
#  'management': 39420,
#  'prioritization': 52209,
#  'execution': 25143,
#  'multi': 43176,
#  'stressful': 66309,
#  'fast': 26595,
#  'pace': 47470,
#  'attention': 6614,
#  'interpret': 34658,
#  'directions': 19932,
#  'operationsmanager': 46058,
#  'qualificationsto': 55017,
#  'successfully': 66719,
#  'individual': 33225,
#  'function': 28562,
#  'satisfactorily': 60412,
#  'requirements': 57650,
#  'list': 38412,
#  'description': 18297,
#  'representative': 57176,
#  'skill': 62923,
#  'require': 57336,
#  'reasonable': 55782,
#  'accommodations': 1967,
#  'may': 40860,
#  'enable': 22830,
#  'individuals': 33245,
#  'qualify': 55040,
#  'disabilities': 20025,
#  'requirementsbasic': 57695,
#  'operator': 46105,
#  'general': 29104,
#  'physical': 49394,
#  'demandsrequires': 17962,
#  'walk': 76005,
#  'stand': 65447,
#  'carry': 10736,
#  'materials': 40682,
#  'stoop': 65950,
#  'kneel': 36618,
#  'bend': 8111,
#  'waist': 75991,
#  'reach': 55700,
#  'overhead': 47282,
#  'climb': 12416,
#  'stairs': 65361,
#  'sit': 62739,
#  'long': 38754,
#  'periods': 48702,
#  'lift': 38195,
#  '50': 1150,
#  'lbs': 37425,
#  'occasionally': 45197,
#  'environmentwork': 23979,
#  'diverse': 20356,
#  'some': 64387,
#  'manufacture': 40176,
#  'extensive': 26212,
#  'automobile': 7045,
#  'exposure': 26154,
#  'move': 43031,
#  'mechanical': 41018,
#  'fume': 28554,
#  'airborne': 3591,
#  'particles': 47847,
#  'dirt': 20018,
#  'dust': 21259,
#  'chemical': 11722,
#  'noise': 44599,
#  'usually': 74775,
#  'moderate': 42536,
#  'loud': 38814,
#  'hear': 30991,
#  'protection': 54306,
#  'shoe': 62334,
#  'eye': 26290,
#  'temperature': 69534,
#  'range': 55561,
#  'approximately': 5441,
#  '30': 855,
#  '110': 167,
#  'summarythis': 66930,
#  'identify': 32270,
#  'expectations': 25321,
#  'performance': 48567,
#  'qualifications': 54931,
#  'outline': 47164,
#  'content': 14760,
#  'it': 35350,
#  'neither': 44132,
#  'intend': 34385,
#  'variables': 75037,
#  'employee': 22698,
#  'condition': 14213,
#  'subject': 66565,
#  'employees': 22704,
#  'expect': 25315,
#  'assign': 6282,
#  'equal': 24051,
#  'employer': 22766,
#  'workforce': 77262,
#  'url_c379aa631173ed5b7c345ab3f500a9a053e509138ca70e52c1088e5a784dc8d7': 74190,
#  'modern': 42541,
#  'travel': 71700,
#  'athens': 6535,
#  '2005': 524,
#  'today': 70839,
#  'lead': 37451,
#  'agencies': 3362,
#  'greece': 29999,
#  'presence': 51853,
#  '25': 741,
#  'countries': 15448,
#  'europe': 24732,
#  'asia': 6094,
#  'america': 3992,
#  'bucharest': 9420,
#  'sao': 60322,
#  'paulo': 48182,
#  'trainee': 71433,
#  'update': 72900,
#  'hotel': 31632,
#  'website': 76361,
#  'optimize': 46391,
#  'information': 33520,
#  'section': 61158,
#  'conduct': 14246,
#  'map': 40206,
#  'hotels': 31640,
#  'regions': 56368,
#  'tourism': 71260,
#  'would': 77523,
#  'consider': 14507,
#  'asset': 6215,
#  'priority': 52227,
#  'students': 66403,
#  'tei': 69432,
#  'iek': 32326,
#  'colleges': 13013,
#  'fluency': 27602,
#  'english': 23196,
#  'excellent': 25050,
#  'creative': 15708,
#  'spirit': 64870,
#  'geography': 29207,
#  'desire': 18740,
#  'continuous': 14863,
#  'improvement': 32779,
#  'category': 10883,
#  'tech': 69028,
#  'support': 67172,
#  'desk': 18789,
#  'engineerno': 23109,
#  '33qualification': 929,
#  'any': 4699,
#  'me': 40961,
#  'graduatesno': 29871,
#  'percentage': 48523,
#  'criteria': 15823,
#  'bangalore': 7541,
#  'hyderabadcompensation': 32014,
#  '8l': 1529,
#  'ait': 3626,
#  'rotational': 59703,
#  'shift': 62270,
#  'cab': 9947,
#  'facility': 26384,
#  'should': 62401,
#  'teachers': 68520,
#  'secure': 61203,
#  'abroad': 1834,
#  'kid': 36509,
#  'pay': 48197,
#  '1500': 296,
#  'usd': 74585,
#  'monthly': 42754,
#  '200': 512,
#  'student': 66396,
#  'loan': 38561,
#  'credit': 15766,
#  'cardshousing': 10612,
#  'furnish': 28766,
#  'airfare': 3598,
#  'reimbursedremind': 56488,
#  'start': 65610,
#  'university': 72691,
#  'tefl': 69428,
#  'tesol': 69706,
#  'celta': 11036,
#  'teach': 68512,
#  'necessarypositive': 43768,
#  'attitude': 6637,
#  'canada': 10327,
#  'passport': 48047,
#  'holders': 31439,
#  'valor': 74952,
#  'solutions': 64122,
#  'sector': 61163,
#  'special': 64657,
#  'focus': 27659,
#  'oil': 45592,
#  'gas': 28958,
#  'involve': 34939,
#  'throughout': 70398,
#  'step': 65852,
#  'hire': 31323,
#  'contact': 14714,
#  'way': 76167,
#  'final': 27154,
#  'sign': 62501,
#  'employment': 22777,
#  'contract': 14871,
#  'vision': 75581,
#  'employ': 22695,
#  'unique': 72648,
#  'qualities': 55049,
#  'finest': 27229,
#  'veterans': 75384,
#  'precise': 51488,
#  'concert': 14166,
#  'value': 74958,
#  'career': 10634,
#  'eager': 21429,
#  'word': 77091,
#  'ample': 4041,
#  'opportunities': 46154,
#  'ideal': 32165,
#  'candidates': 10378,
#  'fill': 27137,
#  'your': 78084,
#  'success': 66690,
#  'client': 12167,
#  'houston': 31750,
#  'actively': 2511,
#  'pipe': 49517,
#  'fitter': 27353,
#  'dependable': 18178,
#  'flexible': 27481,
#  'ethic': 24609,
#  'well': 76574,
#  'candidate': 10352,
#  'lay': 37381,
#  'cut': 16548,
#  'associate': 6427,
#  'fittings': 27357,
#  'flanges': 27405,
#  'verify': 75304,
#  'per': 48520,
#  'isometric': 35162,
#  'draw': 20978,
#  'fabricate': 26322,
#  'components': 13935,
#  'pip': 49516,
#  'assemblies': 6175,
#  'sub': 66542,
#  'defective': 17583,
#  'questionable': 55228,
#  'department': 18077,
#  'supervisor': 67062,
#  'schedule': 60616,
#  'minimum': 42157,
#  'supervision': 67008,
#  'safely': 60002,
#  'orderly': 46482,
#  'thorough': 70327,
#  'material': 40655,
#  '75': 1402,
#  'crane': 15647,
#  'school': 60747,
#  'diploma': 19861,
#  'equivalent': 24153,
#  'yrs': 78133,
#  'fit': 27340,
#  'overview': 47335,
#  'technological': 69156,
#  'leader': 37461,
#  'creativity': 15743,
#  'empower': 22803,
#  'cities': 11956,
#  'smarter': 63676,
#  'complex': 13867,
#  'and': 4348,
#  'smartphone': 63686,
#  'save': 60433,
#  'everyday': 24901,
#  'challenge': 11302,
#  'how': 31755,
#  'contribute': 14936,
#  'reinvent': 56502,
#  'public': 54580,
#  'transport': 71656,
#  'app': 4849,
#  'winner': 76910,
#  'mobile': 42382,
#  'berlin': 8233,
#  'hackescher': 30513,
#  'markt': 40559,
#  'rooftop': 59655,
#  'terrace': 69672,
#  'plunge': 50257,
#  'pool': 50772,
#  'great': 29981,
#  'improve': 32769,
#  'allryder': 3839,
#  'civic': 11994,
#  'startups': 65669,
#  'recruit': 56096,
#  'variety': 75059,
#  'hr': 31781,
#  'development': 19180,
#  'project': 53756,
#  'marketers': 40319,
#  'crm': 15858,
#  'social': 63828,
#  'media': 41042,
#  'pr': 51274,
#  'communities': 13386,
#  'assurance': 6465,
#  'designers': 18520,
#  'ui': 72325,
#  'ux': 74843,
#  'visual': 75657,
#  'developers': 19111,
#  'backend': 7315,
#  'anyone': 4711,
#  'rat': 55600,
#  'depend': 18175,
#  'person': 48780,
#  'ryanair': 59941,
#  'favourite': 26638,
#  'low': 38851,
#  'fare': 26548,
#  'airline': 3603,
#  '600': 1278,
#  'daily': 16709,
#  'flight': 27513,
#  '500': 1151,
#  '000': 1,
#  'year': 77881,
#  '69': 1334,
#  'rout': 59727,
#  'connect': 14429,
#  '186': 381,
#  'destinations': 18821,
#  'fleet': 27448,
#  '300': 856,
#  'boeing': 8740,
#  '737': 1394,
#  '800': 1464,
#  'aircraft': 3595,
#  'recently': 55847,
#  'announce': 4606,
#  '180': 359,
#  '2014': 593,
#  '2018': 638,
#  'currently': 16299,
#  'skilled': 62927,
#  'professionals': 53325,
#  '86': 1503,
#  'million': 42048,
#  'outstanding': 47242,
#  'always': 3915,
#  'better': 8294,
#  'campaign': 10187,
#  'senior': 61426,
#  'customer': 16327,
#  'on1': 45708,
#  'outsource': 47236,
#  'centre': 11082,
#  'romania': 59641,
#  'hungary': 31963,
#  'primarily': 52067,
#  'overall': 47265,
#  'main': 39181,
#  'objective': 45034,
#  'on2': 45709,
#  'ensure': 23407,
#  'satisfaction': 60379,
#  'develop': 19059,
#  'achieve': 2331,
#  'target': 68186,
#  'relationships': 56570,
#  'units': 72659,
#  'stakeholders': 65368,
#  'vital': 75689,
#  'link': 38328,
#  'remote': 56816,
#  'internally': 34560,
#  'name': 43501,
#  'confuse': 14412,
#  'novitex': 44776,
#  'enterprise': 23422,
#  'formerly': 27991,
#  'pitney': 49587,
#  'bow': 9012,
#  'innovative': 33905,
#  'document': 20503,
#  'communications': 13288,
#  'around': 5922,
#  'efficiencies': 21886,
#  'increase': 33043,
#  'productivity': 53041,
#  'reduce': 56210,
#  'for': 27813,
#  'almost': 3850,
#  'clients': 12221,
#  'turn': 72086,
#  'integrate': 34258,
#  'wide': 76775,
#  'maximize': 40849,
#  'trust': 71976,
#  'enhance': 23330,
#  'interactions': 34422,
#  'growth': 30195,
#  'indianapolis': 33178,
#  'integral': 34254,
#  'talented': 68114,
#  'continue': 14858,
#  'clientscanning': 12256,
#  'mfd': 41865,
#  'trooperlitigation': 71918,
#  'scan': 60550,
#  'check': 11630,
#  'scanningupdating': 60572,
#  'listspick': 38457,
#  'mail': 39122,
#  'parcel': 47768,
#  'copy': 15214,
#  'fax': 26640,
#  'customerslift': 16453,
#  'paperhandle': 47690,
#  'sensitive': 61468,
#  'confidential': 14305,
#  'urgent': 73087,
#  'documentsmaintain': 20616,
#  'copier': 15201,
#  'equipmentmaintain': 24106,
#  'highest': 31264,
#  'demonstrate': 18009,
#  'cooperative': 15160,
#  'attitudedemonstrate': 6664,
#  'flexibility': 27468,
#  'satisfy': 60417,
#  'demand': 17942,
#  'volume': 75798,
#  'production': 52980,
#  'environmentconsistently': 23650,
#  'adhere': 2775,
#  'procedure': 52395,
#  'guidelinestake': 30387,
#  'direction': 19904,
#  'site': 62742,
#  'managerparticipate': 39858,
#  'trainingmaintain': 71489,
#  'log': 38671,
#  'documentation': 20508,
#  'detailadhere': 18839,
#  'proceduresperform': 52478,
#  'months': 42762,
#  'requiredhigh': 57460,
#  'ged': 29053,
#  'requiredpreferred': 57542,
#  'keyboarding': 36447,
#  'windows': 76880,
#  'pc': 48304,
#  'excel': 24990,
#  'powerpoint': 51203,
#  'post': 51064,
#  'plusexcellent': 50353,
#  'writtenlifting': 77643,
#  '55': 1209,
#  'without': 77004,
#  'accommodationswillingness': 1985,
#  'availability': 7086,
#  'hours': 31672,
#  'assignedwillingness': 6329,
#  'submit': 66603,
#  ...}

# %% [markdown]
# # SGDClassifier

# %%
sgd = SGDClassifier(loss="modified_huber", penalty="l2", shuffle=True, random_state=420)
sgd.fit(X_train_tfidf, y_train)
y_predicted_sgd = sgd.predict(X_test_tfidf)
print(classification_report(y_test, y_predicted_sgd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3428
#            1       0.98      0.81      0.89       148
#
#     accuracy                           0.99      3576
#    macro avg       0.98      0.90      0.94      3576
# weighted avg       0.99      0.99      0.99      3576

# %% [markdown]
# # Logistic Regression

# %%
log = LogisticRegression(C=42.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', random_state=42)
log.fit(X_train_tfidf, y_train)
y_predicted_log = log.predict(X_test_tfidf)

print(classification_report(y_test, y_predicted_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      3428
#            1       0.84      0.89      0.86       148
#
#     accuracy                           0.99      3576
#    macro avg       0.92      0.94      0.93      3576
# weighted avg       0.99      0.99      0.99      3576

# %% [markdown]
# # Complement Naive Bayes

# %%
cnb = ComplementNB()
cnb.fit(X_train_tfidf, y_train)
y_predicted_cnb = cnb.predict(X_test_tfidf)

print(classification_report(y_test, y_predicted_cnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      3428
#            1       0.14      0.01      0.01       148
#
#     accuracy                           0.96      3576
#    macro avg       0.55      0.50      0.50      3576
# weighted avg       0.93      0.96      0.94      3576

# %% [markdown]
# # Random Forest Classifier

# %%
regr=RandomForestClassifier(n_estimators = 200, max_features = "sqrt", random_state = 420)
regr.fit(X_train_tfidf,y_train)
y_predicted_regr = regr.predict(X_test_tfidf)

print(classification_report(y_test,y_predicted_regr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3428
#            1       1.00      0.71      0.83       148
#
#     accuracy                           0.99      3576
#    macro avg       0.99      0.85      0.91      3576
# weighted avg       0.99      0.99      0.99      3576
